# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import MisrToolkit as mtk # needs python3.6
# from mpl_toolkits.basemap import Basemap # needs python 3.8?
import sys # to check python version
import os
import glob

# %% [markdown]
# # Extract data from MISR-estimated roughness files by using MTK library. Should use python3.6 for this purpose

# %% [markdown]
# ## Plot Transect

# %%
atm_file = "insample_atm_withPathOrbit_3cams_forTransect.csv"
atm_dir = "/media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/training_data"
atm_data_fp = os.path.join(atm_dir, atm_file)

# %%
transect_small = pd.read_csv(atm_data_fp)
transect_small
# Out:
#       Unnamed: 0  path  orbit        lat         lon     Ca_r     Cf_r  \
# 0              1   152  86922  74.422639  215.545163  0.84397  1.39007
# 1              2   152  86922  74.422351  215.546735  0.83645  1.39609
# 2              3   152  86922  74.422064  215.548307  0.83645  1.39609
# 3              4   152  86922  74.422294  215.547049  0.83645  1.39609
# 4              5   152  86922  74.422393  215.544545  0.84397  1.39007
# ...          ...   ...    ...        ...         ...      ...      ...
# 9995        9996    79  86932  74.244492  215.095957  0.85789  0.96812
# 9996        9997    79  86932  74.244203  215.097542  0.85789  0.96812
# 9997        9998    79  86932  74.244466  215.096102  0.85789  0.96812
# 9998        9999    79  86932  74.244545  215.093780  0.85494  0.96673
# 9999       10000    79  86932  74.244252  215.095348  0.85754  0.95754
#
#          An_r   rms
# 0     0.59725  5.19
# 1     0.58973  5.72
# 2     0.58973  6.33
# 3     0.58973  5.97
# 4     0.59725  5.18
# ...       ...   ...
# 9995  0.80035  6.02
# 9996  0.80035  7.34
# 9997  0.80035  6.13
# 9998  0.80104  7.45
# 9999  0.79689  5.67
#
# [10000 rows x 9 columns]

# %%
transect_small = transect_small.iloc[0:1000]
transect_small.iloc[0]
# Out:
# Unnamed: 0        1.000000
# path            152.000000
# orbit         86922.000000
# lat              74.422639
# lon             215.545163
# Ca_r              0.843970
# Cf_r              1.390070
# An_r              0.597250
# rms               5.190000
# Name: 0, dtype: float64

# %%
roughness_dir = "/media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH"

# %%
# # extract MISR-estimated roughness for the same latLon locations and plot them together with ATM
# transect_from_misr = []
# for irow in range(transect_small.shape[0]): # each row==LatLon might fall in several blocks==POB, we open each block and will average all at the end
    
#     print("DF row: %s" %irow)
#     lat_lon = transect_small[['lat','lon']].iloc[irow]
#     print(lat_lon)
    
#     path_list = mtk.latlon_to_path_list(lat_lon[0], lat_lon[1])
#     print(path_list)
    
#     roughness_per_pixel_list = []
#     for path in path_list:
#         # Q- now that we have found many paths, how figure out to select which path?
#         bls = mtk.latlon_to_bls(path, 275 , lat_lon[0], lat_lon[1])
#         print(bls)
        
#         # use P and B to find roughness file, open it, and extract value for LS, append it to a list, and maybe finally append the list to DF as the last column
#         if path < 100:
#             print(path)
#             path_str = str(path).zfill(3)
#             print(path_str)
            
#         roughness_filepattern = "roughness_toa_refl_P"+path_str+"_*"+"_B0"+str(bls[0])+".dat"
#         print(roughness_filepattern)
#         rough_file_fp = os.path.join(roughness_dir, roughness_filepattern)
#         print(rough_file_fp)
        
#         # check if file is found on machine
#         roughness_file_found_list = glob.glob(os.path.join(roughness_dir, roughness_filepattern))
#         print("roughness file found: %d" %len(roughness_file_found_list))
        
#         if (len(roughness_file_found_list) > 1):
#             raise ValueError('more than 1 file found, there is a problem with this code and it has to be reviewed.')
        
#         if (len(roughness_file_found_list) <= 0):
#             print("roughness file not found- continue to next path")
#             continue
            
#         # open roughness file and read pixel value- chat binary format to 2D array and read pixel value
#         rough_2d_arr = np.fromfile(roughness_file_found_list[0], dtype=np.double)[0:1048576].reshape((512,-1))
#         print(rough_2d_arr.shape)
        
#         pixel_row = bls[1]
#         pixel_col = bls[2]
#         roughness_value = rough_2d_arr[int(pixel_row), int(pixel_col)]
#         if roughness_value > 0:
#             roughness_per_pixel_list.append(roughness_value)
    
#     print("========================== extracted rough pixels ===========================")
#     print(roughness_per_pixel_list)
#     mean_roughness_per_pixel = sum(roughness_per_pixel_list)/len(roughness_per_pixel_list)
#     roughness_per_pixel_list.clear()
#     print(roughness_per_pixel_list)
#     print(mean_roughness_per_pixel)
#     print("\n")
#     transect_from_misr.append(mean_roughness_per_pixel)

# %%
# extract MISR-estimated roughness for the same latLon locations and plot them together with ATM
transect_from_misr_list = []

for irow in range(transect_small.shape[0]): # each row==LatLon might fall in several blocks==POB, we open each block and will average all at the end
    
    print("DF row: %s" %irow)
    poll = transect_small[['path','orbit','lat','lon']].iloc[irow]
#     print(poll)
    
    path_int = int(poll[0])
    orbit_int = int(poll[1])
    lat = poll[2]
    lon = poll[3]
    
#     print("path: %s" %path_int)
#     print("orbit: %s" %orbit_int)
#     print("lat: %s" %lat)
#     print("lon: %s" %lon)
    
    
    # Q- now that we have found many paths, how figure out to select which path?
    bls = mtk.latlon_to_bls(path_int, 275 , lat, lon)
    print("block-line-sample: (%s, %s, %s)" %bls)
    
    block = bls[0]
    if block < 10:
        block_str = str(block).zfill(2)


    # use P and B to find roughness file, open it, and extract value for LS, append it to a list, and maybe finally append the list to DF as the last column
    if path_int < 100:
        print(path_int)
        path_str = str(path_int).zfill(3)
        print(path_str)
    else:
        path_str = str(path_int)
        
        
    # find the pattern
    roughness_filepattern = "roughness_toa_refl_P"+path_str+"_O0"+str(orbit_int)+"_B0"+block_str+".dat"
    print(roughness_filepattern)
    
    rough_file_fp = os.path.join(roughness_dir, roughness_filepattern)
    print(rough_file_fp)

    # check if file is found on machine
    roughness_file_found_list = glob.glob(os.path.join(roughness_dir, roughness_filepattern))
    print("roughness file found: %d" %len(roughness_file_found_list))

    if (len(roughness_file_found_list) > 1):
        raise ValueError('more than 1 file found, there is a problem with this code and it has to be reviewed.')

    if (len(roughness_file_found_list) <= 0):
        print("roughness file not found- continue to next path")
        continue

    # open roughness file and read pixel value- chat binary format to 2D array and read pixel value
    rough_2d_arr = np.fromfile(roughness_file_found_list[0], dtype=np.double)[0:1048576].reshape((512,-1))
    print(rough_2d_arr.shape)

    pixel_row = int(bls[1])
    pixel_col = int(bls[2])
    
    roughness_per_pixel = rough_2d_arr[pixel_row, pixel_col]
    print(roughness_per_pixel)
    
    if roughness_per_pixel < 0:
        continue
    else:
        transect_from_misr_list.append(roughness_per_pixel)
# Out:
# DF row: 0
# block-line-sample: (9, 75.14599609375, 1205.602294921875)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 14.04774923042274
# DF row: 1
# block-line-sample: (9, 74.95361328125, 1205.524169921875)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 13.894023617518537
# DF row: 2
# block-line-sample: (9, 74.76171875, 1205.4459228515625)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 13.894023617518537
# DF row: 3
# block-line-sample: (9, 74.91552734375, 1205.508544921875)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 13.894023617518537
# DF row: 4
# block-line-sample: (9, 75.10009765625, 1205.713623046875)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 14.04774923042274
# DF row: 5
# block-line-sample: (9, 74.908203125, 1205.6356201171875)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 13.894023617518537
# DF row: 6
# block-line-sample: (9, 74.7158203125, 1205.5576171875)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 13.894023617518537
# DF row: 7
# block-line-sample: (9, 74.86962890625, 1205.6202392578125)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 13.894023617518537
# DF row: 8
# block-line-sample: (9, 75.05517578125, 1205.8243408203125)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 14.04774923042274
# DF row: 9
# block-line-sample: (9, 74.8623046875, 1205.7469482421875)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 13.894023617518537
# DF row: 10
# block-line-sample: (9, 74.669921875, 1205.6695556640625)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 13.894023617518537
# DF row: 11
# block-line-sample: (9, 74.82373046875, 1205.731201171875)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 13.894023617518537
# DF row: 12
# block-line-sample: (9, 75.01025390625, 1205.93359375)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 14.04774923042274
# DF row: 13
# block-line-sample: (9, 74.81787109375, 1205.856201171875)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 13.894023617518537
# DF row: 14
# block-line-sample: (9, 74.6259765625, 1205.7784423828125)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 13.894023617518537
# DF row: 15
# block-line-sample: (9, 74.779296875, 1205.840576171875)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 13.894023617518537
# DF row: 16
# block-line-sample: (9, 74.96533203125, 1206.0438232421875)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 15.796213933221399
# DF row: 17
# block-line-sample: (9, 74.77392578125, 1205.9649658203125)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 13.894023617518537
# DF row: 18
# block-line-sample: (9, 74.58203125, 1205.8863525390625)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 13.894023617518537
# DF row: 19
# block-line-sample: (9, 74.736328125, 1205.9498291015625)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 13.894023617518537
# DF row: 20
# block-line-sample: (9, 74.919921875, 1206.1549072265625)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 15.796213933221399
# DF row: 21
# block-line-sample: (9, 74.72802734375, 1206.0771484375)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 15.796213933221399
# DF row: 22
# block-line-sample: (9, 74.5361328125, 1205.9993896484375)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 13.894023617518537
# DF row: 23
# block-line-sample: (9, 74.68994140625, 1206.0614013671875)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 15.796213933221399
# DF row: 24
# block-line-sample: (9, 74.87451171875, 1206.2655029296875)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 15.796213933221399
# DF row: 25
# block-line-sample: (9, 74.6826171875, 1206.1876220703125)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 15.796213933221399
# DF row: 26
# block-line-sample: (9, 74.490234375, 1206.10986328125)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 15.796213933221399
# DF row: 27
# block-line-sample: (9, 74.64453125, 1206.17236328125)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 15.796213933221399
# DF row: 28
# block-line-sample: (9, 74.82861328125, 1206.376708984375)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 15.796213933221399
# DF row: 29
# block-line-sample: (9, 74.63720703125, 1206.2982177734375)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 15.796213933221399
# DF row: 30
# block-line-sample: (9, 74.44580078125, 1206.21923828125)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 15.796213933221399
# DF row: 31
# block-line-sample: (9, 74.6005859375, 1206.2830810546875)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 15.796213933221399
# DF row: 32
# block-line-sample: (9, 74.78662109375, 1206.48388671875)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 15.796213933221399
# DF row: 33
# block-line-sample: (9, 74.59228515625, 1206.4063720703125)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 15.796213933221399
# DF row: 34
# block-line-sample: (9, 74.3974609375, 1206.3292236328125)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 15.796213933221399
# DF row: 35
# block-line-sample: (9, 74.5537109375, 1206.391357421875)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 15.796213933221399
# DF row: 36
# block-line-sample: (9, 74.73828125, 1206.595703125)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 15.796213933221399
# DF row: 37
# block-line-sample: (9, 74.5458984375, 1206.5167236328125)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 15.796213933221399
# DF row: 38
# block-line-sample: (9, 74.35400390625, 1206.4376220703125)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 15.796213933221399
# DF row: 39
# block-line-sample: (9, 74.51123046875, 1206.5025634765625)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 15.796213933221399
# DF row: 40
# block-line-sample: (9, 74.69287109375, 1206.7064208984375)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 15.796213933221399
# DF row: 41
# block-line-sample: (9, 74.49951171875, 1206.6279296875)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 15.796213933221399
# DF row: 42
# block-line-sample: (9, 74.306640625, 1206.549072265625)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 15.796213933221399
# DF row: 43
# block-line-sample: (9, 74.46533203125, 1206.61376953125)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 15.796213933221399
# DF row: 44
# block-line-sample: (9, 74.6455078125, 1206.8175048828125)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 15.796213933221399
# DF row: 45
# block-line-sample: (9, 74.453125, 1206.7388916015625)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 15.796213933221399
# DF row: 46
# block-line-sample: (9, 74.26025390625, 1206.6602783203125)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 15.796213933221399
# DF row: 47
# block-line-sample: (9, 74.41943359375, 1206.725341796875)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 15.796213933221399
# DF row: 48
# block-line-sample: (9, 74.6005859375, 1206.926513671875)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 15.796213933221399
# DF row: 49
# block-line-sample: (9, 74.4072265625, 1206.8485107421875)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 15.796213933221399
# DF row: 50
# block-line-sample: (9, 74.21435546875, 1206.7703857421875)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 15.796213933221399
# DF row: 51
# block-line-sample: (9, 74.3740234375, 1206.8349609375)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 15.796213933221399
# DF row: 52
# block-line-sample: (9, 74.5546875, 1207.0352783203125)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 20.14181081814584
# DF row: 53
# block-line-sample: (9, 74.36181640625, 1206.957275390625)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 15.796213933221399
# DF row: 54
# block-line-sample: (9, 74.1689453125, 1206.8792724609375)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 15.796213933221399
# DF row: 55
# block-line-sample: (9, 74.32958984375, 1206.9442138671875)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 15.796213933221399
# DF row: 56
# block-line-sample: (9, 74.50830078125, 1207.1463623046875)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 20.14181081814584
# DF row: 57
# block-line-sample: (9, 74.3154296875, 1207.068603515625)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 20.14181081814584
# DF row: 58
# block-line-sample: (9, 74.12255859375, 1206.9908447265625)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 15.796213933221399
# DF row: 59
# block-line-sample: (9, 74.283203125, 1207.0556640625)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 20.14181081814584
# DF row: 60
# block-line-sample: (9, 74.4609375, 1207.2593994140625)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 20.14181081814584
# DF row: 61
# block-line-sample: (9, 74.26904296875, 1207.18115234375)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 20.14181081814584
# DF row: 62
# block-line-sample: (9, 74.0771484375, 1207.1029052734375)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 20.14181081814584
# DF row: 63
# block-line-sample: (9, 74.23876953125, 1207.16845703125)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 20.14181081814584
# DF row: 64
# block-line-sample: (9, 74.4150390625, 1207.36962890625)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 20.14181081814584
# DF row: 65
# block-line-sample: (9, 74.2236328125, 1207.291015625)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 20.14181081814584
# DF row: 66
# block-line-sample: (9, 74.03271484375, 1207.212158203125)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 20.14181081814584
# DF row: 67
# block-line-sample: (9, 74.1943359375, 1207.2786865234375)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 20.14181081814584
# DF row: 68
# block-line-sample: (9, 74.3701171875, 1207.478515625)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 20.14181081814584
# DF row: 69
# block-line-sample: (9, 74.17919921875, 1207.39990234375)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 20.14181081814584
# DF row: 70
# block-line-sample: (9, 73.98779296875, 1207.3212890625)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 19.874243364310047
# DF row: 71
# block-line-sample: (9, 74.1494140625, 1207.3878173828125)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 20.14181081814584
# DF row: 72
# block-line-sample: (9, 74.32568359375, 1207.587890625)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 20.14181081814584
# DF row: 73
# block-line-sample: (9, 74.1337890625, 1207.510009765625)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 20.14181081814584
# DF row: 74
# block-line-sample: (9, 73.94189453125, 1207.43212890625)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 19.874243364310047
# DF row: 75
# block-line-sample: (9, 74.103515625, 1207.4976806640625)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 20.14181081814584
# DF row: 76
# block-line-sample: (9, 74.27978515625, 1207.698974609375)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 20.14181081814584
# DF row: 77
# block-line-sample: (9, 74.08837890625, 1207.6207275390625)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 20.14181081814584
# DF row: 78
# block-line-sample: (9, 73.89697265625, 1207.5423583984375)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 19.874243364310047
# DF row: 79
# block-line-sample: (9, 74.05908203125, 1207.608642578125)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 20.14181081814584
# DF row: 80
# block-line-sample: (9, 74.2353515625, 1207.8084716796875)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 20.14181081814584
# DF row: 81
# block-line-sample: (9, 74.04296875, 1207.730712890625)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 20.14181081814584
# DF row: 82
# block-line-sample: (9, 73.85107421875, 1207.65283203125)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 19.874243364310047
# DF row: 83
# block-line-sample: (9, 74.01318359375, 1207.7183837890625)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 20.14181081814584
# DF row: 84
# block-line-sample: (9, 74.1884765625, 1207.9215087890625)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 20.14181081814584
# DF row: 85
# block-line-sample: (9, 73.99755859375, 1207.8427734375)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 19.874243364310047
# DF row: 86
# block-line-sample: (9, 73.80615234375, 1207.76416015625)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 19.874243364310047
# DF row: 87
# block-line-sample: (9, 73.96826171875, 1207.8310546875)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 19.874243364310047
# DF row: 88
# block-line-sample: (9, 74.14453125, 1208.0306396484375)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 19.301668925213264
# DF row: 89
# block-line-sample: (9, 73.953125, 1207.95068359375)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 19.874243364310047
# DF row: 90
# block-line-sample: (9, 73.76171875, 1207.870361328125)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 19.874243364310047
# DF row: 91
# block-line-sample: (9, 73.92578125, 1207.93896484375)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 19.874243364310047
# DF row: 92
# block-line-sample: (9, 74.09912109375, 1208.139892578125)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 19.301668925213264
# DF row: 93
# block-line-sample: (9, 73.90771484375, 1208.061279296875)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 20.739341307123258
# DF row: 94
# block-line-sample: (9, 73.71630859375, 1207.9825439453125)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 19.874243364310047
# DF row: 95
# block-line-sample: (9, 73.87890625, 1208.0494384765625)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 20.739341307123258
# DF row: 96
# block-line-sample: (9, 74.05322265625, 1208.2518310546875)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 19.301668925213264
# DF row: 97
# block-line-sample: (9, 73.86181640625, 1208.173095703125)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 20.739341307123258
# DF row: 98
# block-line-sample: (9, 73.67041015625, 1208.094482421875)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 20.739341307123258
# DF row: 99
# block-line-sample: (9, 73.8330078125, 1208.161376953125)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 20.739341307123258
# DF row: 100
# block-line-sample: (9, 74.00830078125, 1208.3604736328125)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 19.301668925213264
# DF row: 101
# block-line-sample: (9, 73.8173828125, 1208.2813720703125)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 20.739341307123258
# DF row: 102
# block-line-sample: (9, 73.6259765625, 1208.202392578125)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 20.739341307123258
# DF row: 103
# block-line-sample: (9, 73.7890625, 1208.2696533203125)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 20.739341307123258
# DF row: 104
# block-line-sample: (9, 73.96240234375, 1208.471923828125)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 20.739341307123258
# DF row: 105
# block-line-sample: (9, 73.77099609375, 1208.393310546875)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 20.739341307123258
# DF row: 106
# block-line-sample: (9, 73.57958984375, 1208.3148193359375)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 20.739341307123258
# DF row: 107
# block-line-sample: (9, 73.74267578125, 1208.381591796875)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 20.739341307123258
# DF row: 108
# block-line-sample: (9, 73.9169921875, 1208.582275390625)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 20.739341307123258
# DF row: 109
# block-line-sample: (9, 73.7255859375, 1208.5035400390625)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 20.739341307123258
# DF row: 110
# block-line-sample: (9, 73.5341796875, 1208.4249267578125)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 20.739341307123258
# DF row: 111
# block-line-sample: (9, 73.697265625, 1208.491943359375)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 20.739341307123258
# DF row: 112
# block-line-sample: (9, 73.87109375, 1208.6934814453125)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 20.739341307123258
# DF row: 113
# block-line-sample: (9, 73.6796875, 1208.6142578125)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 20.739341307123258
# DF row: 114
# block-line-sample: (9, 73.4892578125, 1208.5347900390625)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 20.739341307123258
# DF row: 115
# block-line-sample: (9, 73.6533203125, 1208.602783203125)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 20.739341307123258
# DF row: 116
# block-line-sample: (9, 73.826171875, 1208.802978515625)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 20.739341307123258
# DF row: 117
# block-line-sample: (9, 73.63427734375, 1208.724609375)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 20.739341307123258
# DF row: 118
# block-line-sample: (9, 73.4423828125, 1208.64599609375)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 20.739341307123258
# DF row: 119
# block-line-sample: (9, 73.60693359375, 1208.713134765625)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 20.739341307123258
# DF row: 120
# block-line-sample: (9, 73.78076171875, 1208.912353515625)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 20.739341307123258
# DF row: 121
# block-line-sample: (9, 73.5888671875, 1208.8338623046875)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 20.739341307123258
# DF row: 122
# block-line-sample: (9, 73.3974609375, 1208.7554931640625)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 20.739341307123258
# DF row: 123
# block-line-sample: (9, 73.5615234375, 1208.8226318359375)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 20.739341307123258
# DF row: 124
# block-line-sample: (9, 73.73486328125, 1209.0255126953125)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 13.89542518038856
# DF row: 125
# block-line-sample: (9, 73.54296875, 1208.9473876953125)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 20.739341307123258
# DF row: 126
# block-line-sample: (9, 73.35107421875, 1208.869384765625)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 20.739341307123258
# DF row: 127
# block-line-sample: (9, 73.5146484375, 1208.93603515625)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 20.739341307123258
# DF row: 128
# block-line-sample: (9, 73.69091796875, 1209.1356201171875)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 13.89542518038856
# DF row: 129
# block-line-sample: (9, 73.49853515625, 1209.056396484375)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 13.89542518038856
# DF row: 130
# block-line-sample: (9, 73.306640625, 1208.9769287109375)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 20.739341307123258
# DF row: 131
# block-line-sample: (9, 73.4716796875, 1209.044921875)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 13.89542518038856
# DF row: 132
# block-line-sample: (9, 73.646484375, 1209.242431640625)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 13.89542518038856
# DF row: 133
# block-line-sample: (9, 73.45458984375, 1209.1641845703125)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 13.89542518038856
# DF row: 134
# block-line-sample: (9, 73.2626953125, 1209.086181640625)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 13.89542518038856
# DF row: 135
# block-line-sample: (9, 73.42626953125, 1209.1524658203125)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 13.89542518038856
# DF row: 136
# block-line-sample: (9, 73.6005859375, 1209.354736328125)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 13.89542518038856
# DF row: 137
# block-line-sample: (9, 73.4091796875, 1209.276123046875)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 13.89542518038856
# DF row: 138
# block-line-sample: (9, 73.216796875, 1209.1978759765625)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 13.89542518038856
# DF row: 139
# block-line-sample: (9, 73.38037109375, 1209.2646484375)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 13.89542518038856
# DF row: 140
# block-line-sample: (9, 73.5556640625, 1209.4658203125)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 13.89542518038856
# DF row: 141
# block-line-sample: (9, 73.36376953125, 1209.3876953125)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 13.89542518038856
# DF row: 142
# block-line-sample: (9, 73.171875, 1209.3096923828125)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 13.89542518038856
# DF row: 143
# block-line-sample: (9, 73.33447265625, 1209.3759765625)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 13.89542518038856
# DF row: 144
# block-line-sample: (9, 73.509765625, 1209.5765380859375)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 13.89542518038856
# DF row: 145
# block-line-sample: (9, 73.31884765625, 1209.4974365234375)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 13.89542518038856
# DF row: 146
# block-line-sample: (9, 73.12744140625, 1209.41845703125)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 13.89542518038856
# DF row: 147
# block-line-sample: (9, 73.29052734375, 1209.48583984375)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 13.89542518038856
# DF row: 148
# block-line-sample: (9, 73.4658203125, 1209.6876220703125)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 13.89542518038856
# DF row: 149
# block-line-sample: (9, 73.27197265625, 1209.6102294921875)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 13.89542518038856
# DF row: 150
# block-line-sample: (9, 73.078125, 1209.5325927734375)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 13.89542518038856
# DF row: 151
# block-line-sample: (9, 73.24169921875, 1209.5982666015625)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 13.89542518038856
# DF row: 152
# block-line-sample: (9, 73.419921875, 1209.796630859375)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 13.89542518038856
# DF row: 153
# block-line-sample: (9, 73.22705078125, 1209.71826171875)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 13.89542518038856
# DF row: 154
# block-line-sample: (9, 73.03369140625, 1209.6400146484375)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 13.89542518038856
# DF row: 155
# block-line-sample: (9, 73.1982421875, 1209.7069091796875)
# ...
# roughness file found: 1
# (512, 2048)
# 11.802111691959617
# DF row: 949
# block-line-sample: (9, 63.44970703125, 1235.00732421875)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 11.800878099979967
# DF row: 950
# block-line-sample: (9, 63.2568359375, 1234.932861328125)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 11.802111691959617
# DF row: 951
# block-line-sample: (9, 63.064453125, 1234.8580322265625)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 11.802111691959617
# DF row: 952
# block-line-sample: (9, 63.23095703125, 1234.9227294921875)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 11.802111691959617
# DF row: 953
# block-line-sample: (9, 63.40576171875, 1235.118408203125)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 11.800878099979967
# DF row: 954
# block-line-sample: (9, 63.21337890625, 1235.04345703125)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 11.800878099979967
# DF row: 955
# block-line-sample: (9, 63.02099609375, 1234.96826171875)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 11.802111691959617
# DF row: 956
# block-line-sample: (9, 63.18896484375, 1235.0338134765625)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 11.800878099979967
# DF row: 957
# block-line-sample: (9, 63.3623046875, 1235.230224609375)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 11.800878099979967
# DF row: 958
# block-line-sample: (9, 63.16943359375, 1235.1553955078125)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 11.800878099979967
# DF row: 959
# block-line-sample: (9, 62.9765625, 1235.080810546875)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 11.601120440583356
# DF row: 960
# block-line-sample: (9, 63.14453125, 1235.1456298828125)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 11.800878099979967
# DF row: 961
# block-line-sample: (9, 63.31884765625, 1235.34033203125)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 11.800878099979967
# DF row: 962
# block-line-sample: (9, 63.1259765625, 1235.2655029296875)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 11.800878099979967
# DF row: 963
# block-line-sample: (9, 62.93310546875, 1235.1910400390625)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 11.601120440583356
# DF row: 964
# block-line-sample: (9, 63.10107421875, 1235.2559814453125)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 11.800878099979967
# DF row: 965
# block-line-sample: (9, 63.27392578125, 1235.453369140625)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 11.800878099979967
# DF row: 966
# block-line-sample: (9, 63.08154296875, 1235.3787841796875)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 11.800878099979967
# DF row: 967
# block-line-sample: (9, 62.8896484375, 1235.303955078125)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 11.601120440583356
# DF row: 968
# block-line-sample: (9, 63.05712890625, 1235.369140625)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 11.800878099979967
# DF row: 969
# block-line-sample: (9, 63.23193359375, 1235.5653076171875)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 11.800878099979967
# DF row: 970
# block-line-sample: (9, 63.0390625, 1235.4891357421875)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 11.800878099979967
# DF row: 971
# block-line-sample: (9, 62.84716796875, 1235.4127197265625)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 11.601120440583356
# DF row: 972
# block-line-sample: (9, 63.015625, 1235.4794921875)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 11.800878099979967
# DF row: 973
# block-line-sample: (9, 63.19189453125, 1235.6767578125)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 11.800878099979967
# DF row: 974
# block-line-sample: (9, 62.9970703125, 1235.6029052734375)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 11.601120440583356
# DF row: 975
# block-line-sample: (9, 62.80224609375, 1235.5289306640625)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 11.601120440583356
# DF row: 976
# block-line-sample: (9, 62.96826171875, 1235.591796875)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 11.601120440583356
# DF row: 977
# block-line-sample: (9, 63.1591796875, 1235.7947998046875)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 11.800878099979967
# DF row: 978
# block-line-sample: (9, 62.96044921875, 1235.717041015625)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 11.601120440583356
# DF row: 979
# block-line-sample: (9, 62.76220703125, 1235.6392822265625)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 11.601120440583356
# DF row: 980
# block-line-sample: (9, 62.92724609375, 1235.7039794921875)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 11.601120440583356
# DF row: 981
# block-line-sample: (9, 63.126953125, 1235.9091796875)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 11.800878099979967
# DF row: 982
# block-line-sample: (9, 62.92431640625, 1235.8294677734375)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 11.601120440583356
# DF row: 983
# block-line-sample: (9, 62.7216796875, 1235.7496337890625)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 11.601120440583356
# DF row: 984
# block-line-sample: (9, 62.88427734375, 1235.8138427734375)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 11.601120440583356
# DF row: 985
# block-line-sample: (9, 63.09375, 1236.0277099609375)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 11.747935947439204
# DF row: 986
# block-line-sample: (9, 62.88671875, 1235.9449462890625)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 11.601120440583356
# DF row: 987
# block-line-sample: (9, 62.6796875, 1235.8619384765625)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 11.601120440583356
# DF row: 988
# block-line-sample: (9, 62.841796875, 1235.9268798828125)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 11.601120440583356
# DF row: 989
# block-line-sample: (9, 63.0595703125, 1236.139404296875)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 11.747935947439204
# DF row: 990
# block-line-sample: (9, 62.8505859375, 1236.05712890625)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 11.731628990775533
# DF row: 991
# block-line-sample: (9, 62.6416015625, 1235.9749755859375)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 11.601120440583356
# DF row: 992
# block-line-sample: (9, 62.79736328125, 1236.0362548828125)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 11.731628990775533
# DF row: 993
# block-line-sample: (9, 63.0244140625, 1236.2559814453125)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 11.747935947439204
# DF row: 994
# block-line-sample: (9, 62.814453125, 1236.1734619140625)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 11.731628990775533
# DF row: 995
# block-line-sample: (9, 62.6044921875, 1236.0911865234375)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 11.731628990775533
# DF row: 996
# block-line-sample: (9, 62.7529296875, 1236.1492919921875)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 11.731628990775533
# DF row: 997
# block-line-sample: (9, 62.98779296875, 1236.3685302734375)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 11.731628990775533
# DF row: 998
# block-line-sample: (9, 62.779296875, 1236.2862548828125)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 11.731628990775533
# DF row: 999
# block-line-sample: (9, 62.57080078125, 1236.2041015625)
# roughness_toa_refl_P152_O086922_B009.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P152_O086922_B009.dat
# roughness file found: 1
# (512, 2048)
# 11.731628990775533

# %%
# atm_day_time = "2016-04-29T11:30:28Z"
# orbit_path = mtk.time_to_orbit_path(atm_day_time)
# orbit_path[1]

# %%
# transect_from_misr_list

# %%
# plot transect
# transect_small["rms"].plot(x=transect_small.index)#, y=transect_small)
# plt.plot(transect_from_misr)

x = transect_small.index
plt.plot(x, transect_small["rms"])
plt.plot(x, transect_from_misr_list)
plt.legend(["ATM obs","MISR-estimated"])

# %%
transect_small.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %% [markdown]
# ## statistics

# %%
transect_small.describe()
# Out:
#         Unnamed: 0    path    orbit          lat          lon         Ca_r  \
# count  1000.000000  1000.0   1000.0  1000.000000  1000.000000  1000.000000
# mean    500.500000   152.0  86922.0    74.388085   215.459594     0.808244
# std     288.819436     0.0      0.0     0.020327     0.052297     0.033499
# min       1.000000   152.0  86922.0    74.355028   215.372687     0.721170
# 25%     250.750000   152.0  86922.0    74.370293   215.413717     0.774370
# 50%     500.500000   152.0  86922.0    74.385319   215.453411     0.815750
# 75%     750.250000   152.0  86922.0    74.407212   215.508867     0.833440
# max    1000.000000   152.0  86922.0    74.422639   215.548307     0.851500
#
#               Cf_r         An_r          rms
# count  1000.000000  1000.000000  1000.000000
# mean      1.367929     0.561710     9.822390
# std       0.030881     0.040172     4.683469
# min       1.299000     0.477330     4.450000
# 25%       1.356630     0.524620     6.187500
# 50%       1.367510     0.582260     8.710000
# 75%       1.392100     0.588597    12.152500
# max       1.424680     0.607780    36.630000

# %% [markdown]
# ## histogram

# %%
transect_small["rms"].hist(bins=20, alpha=1)
# Out:
# <AxesSubplot:>
