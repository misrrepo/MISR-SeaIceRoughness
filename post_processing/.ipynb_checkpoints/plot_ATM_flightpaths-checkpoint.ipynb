# %%
import os
os.environ['PROJ_LIB'] = "/opt/anaconda3/share/proj/"

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.basemap import Basemap # needs python 3.8?
import sys # to check python version
import glob
import datetime as dt

# %% [markdown]
# usage: visualizes ATM paths over the Arctic

# %% [markdown]
# note: runs with python >= 3.8

# %%
# check python version
sys.version
# Out:
# '3.9.12 (main, Apr  5 2022, 01:53:17) \n[Clang 12.0.0 ]'

# %%
# load training dataset
home_dir = "/Users/ehsanmos/MLP_dataset/atmmodel_k_zero_old"
atmmodel = "atmmodel_april_2016_k_zero.csv"
atmmodel_fp = os.path.join(home_dir, atmmodel)
in_ds = pd.read_csv(atmmodel_fp)

# %%
in_ds.head(5)
# Out:
#    #path   orbit   img_block   line   sample   firstLat    firstLon        an  \
# 0    161   86908           6    427     1394  71.773419  205.988687  4.883254
# 1    161   86908           6    426     1394  71.772469  205.989694  4.839653
# 2    161   86908           6    425     1394  71.770103  205.992264  4.752452
# 3    161   86908           6    424     1394  71.767756  205.994964  4.796053
# 4    161   86908           6    423     1394  71.765427  205.997780  4.752452
#
#          ca         cf     rms   weight   npts   cloud       var
# 0  8.022488  16.350180  14.200      1.0    4.0      -1  1.277087
# 1  7.978888  16.350180  11.740      1.0   10.0      -1  2.754643
# 2  7.891687  16.044976   9.062      1.0   10.0      -1  1.456632
# 3  7.848086  15.870574  14.905      1.0   10.0      -1  5.059417
# 4  7.848086  16.044976  12.299      1.0   10.0      -1  3.539888

# %%
# determine range to print based on min, max lat and lon of the data

xlon = in_ds[' firstLon']
ylat = in_ds[' firstLat']


margin = 2 # buffer to add to the range
lat_min = min(ylat) - margin
lat_max = max(ylat) + margin
lon_min = min(xlon) - margin
lon_max = max(xlon) + margin

# %%
print(lat_min)
print(lat_max)
print(lon_min)
print(lon_max)
# Out:
# 69.221079
# 85.250886
# 197.591141
# 276.55053

# %%
from itertools import chain

def draw_map(m, scale=0.2):
    # draw a shaded-relief image
    m.shadedrelief(scale=scale)
    
    # lats and longs are returned as a dictionary
    lats = m.drawparallels(np.linspace(-90, 90, num=7))
    lons = m.drawmeridians(np.linspace(-180, 180, num=18))

    # keys contain the plt.Line2D instances
    lat_lines = chain(*(tup[1][0] for tup in lats.items()))
    lon_lines = chain(*(tup[1][0] for tup in lons.items()))
    all_lines = chain(lat_lines, lon_lines)
    
    # cycle through these lines and set the desired style
    for line in all_lines:
        line.set(linestyle='-', alpha=0.3, color='w')

# %%
def make_the_basemap(XlonSet: list, 
                     YlatSet: list):
    
    fig = plt.figure(figsize=(12, 12))

    basemap = Basemap(projection='ortho', resolution=None, lat_0=90, lon_0=180)

    # locations on map: convert lat and lon to map projection coordinates
    xlons, ylats = basemap(XlonSet, YlatSet)

    plt.plot(xlons, ylats, 'ok', markersize=1)

    # draw a circle on map on 60N  
    basemap.drawparallels([89,80,70], color='red') #, labels='test'????)
    plt.title('Study Region: red line at 80N', fontsize=16)

    draw_map(basemap);
    return 0;

# %%
# run with oython >= 3.8

make_the_basemap(XlonSet=xlon, YlatSet=ylat)
# Out:
# 0

# %%
# xlon_subset = in_ds[' lon']
# ylat_subset = in_ds[' lat']

# %%
# # run with python >= 3.8

# make_the_basemap(xlon_subset, ylat_subset)
