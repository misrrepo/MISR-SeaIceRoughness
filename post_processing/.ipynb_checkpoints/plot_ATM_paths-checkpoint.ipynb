# %% [markdown]
# ## note: should be run with python3.6 to be able to use MTK library

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import MisrToolkit as mtk # needs python3.6
# from mpl_toolkits.basemap import Basemap # needs python 3.8?
import sys # to check python version
import os
import glob

# %%
# check python version
sys.version
# Out:
# '3.6.9 (default, Dec  8 2021, 21:08:43) \n[GCC 8.4.0]'

# %%
# load training dataset
# ds_fp = "/Users/ehsanmos/Documents/RnD/MISR_lab/ML_research/training_dataset/merged_april_2016_9cam3bands.csv"
ds_fp = "/home/ehsan/misr_lab/training_dataset/april_2016/april_2016_parts/merged_april_2016_9cam_4bands_final_dataset_2.csv"
in_ds = pd.read_csv(ds_fp)

# %%
in_ds.head(5)
# Out:
#    path  orbit  block   line   sample        lat         lon     Da_r  \
# 0     0      0      0   0.00     0.00   0.000000    0.000000  0.00000
# 1   152  86922      9  75.15  1205.60  74.422639  215.545163  1.03203
# 2   152  86922      9  74.95  1205.52  74.422351  215.546735  1.03353
# 3   152  86922      9  74.76  1205.45  74.422064  215.548307  1.03353
# 4   152  86922      9  74.92  1205.51  74.422294  215.547049  1.03353
#
#       Ca_r     Ba_r     Aa_r     An_r     An_g     An_b  An_nir     Af_r  \
# 0  0.00000  0.00000  0.00000  0.00000  0.00000  0.00000     0.0  0.00000
# 1  0.84397  0.71459  0.62433  0.59725  0.47642  0.76723   -99.0  0.70105
# 2  0.83645  0.71008  0.61530  0.58973  0.48393  0.76573   -99.0  0.69955
# 3  0.83645  0.71008  0.61530  0.58973  0.48393  0.76573   -99.0  0.69955
# 4  0.83645  0.71008  0.61530  0.58973  0.48393  0.76573   -99.0  0.69955
#
#       Bf_r     Cf_r     Df_r  mean_ATM_roughness
# 0  0.00000  0.00000  0.00000                0.00
# 1  0.92672  1.39007  2.15582                5.19
# 2  0.94627  1.39609  2.15582                5.72
# 3  0.94627  1.39609  2.15582                6.33
# 4  0.94627  1.39609  2.15582                5.97

# %%
in_ds.shape
# Out:
# (2924469, 20)

# %%
ds_3cam = in_ds[["lat", "lon", "Ca_r", "Cf_r", "An_r", "mean_ATM_roughness"]]

# %%
ds_3cam.rename(columns={"mean_ATM_roughness":"rms"}, inplace=True)
# ds_3cam["mean_ATM_roughness"]="rms" # does not work- should use DF.rename()
ds_3cam.columns
# Out:
# /home/ehsan/.local/lib/python3.6/site-packages/pandas/core/frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
# Index(['lat', 'lon', 'Ca_r', 'Cf_r', 'An_r', 'rms'], dtype='object')

# %%
# determine range to print based on min, max lat and lon of the data
# is it necessary?
xlon = ds_3cam['lon']
ylat = ds_3cam['lat']


margin = 2 # buffer to add to the range
lat_min = min(ylat) - margin
lat_max = max(ylat) + margin
lon_min = min(xlon) - margin
lon_max = max(xlon) + margin

# %%
print(lat_min)
print(lat_max)
print(lon_min)
print(lon_max)
# Out:
# -2.0
# 86.250712
# -2.0
# 277.113721

# %%
from itertools import chain

def draw_map(m, scale=0.2):
    # draw a shaded-relief image
    m.shadedrelief(scale=scale)
    
    # lats and longs are returned as a dictionary
    lats = m.drawparallels(np.linspace(-90, 90, num=7))
    lons = m.drawmeridians(np.linspace(-180, 180, num=18))

    # keys contain the plt.Line2D instances
    lat_lines = chain(*(tup[1][0] for tup in lats.items()))
    lon_lines = chain(*(tup[1][0] for tup in lons.items()))
    all_lines = chain(lat_lines, lon_lines)
    
    # cycle through these lines and set the desired style
    for line in all_lines:
        line.set(linestyle='-', alpha=0.3, color='w')

# %%
# ref: https://stackoverflow.com/questions/44488167/plotting-lat-long-points-using-basemap
# basemap = Basemap(llcrnrlon=lon_min,
#                     llcrnrlat=lat_min,
#                     urcrnrlon=lon_max,
#                     urcrnrlat=lat_max,
#                     lat_0=(lat_max - lat_min)/2,
#                     lon_0=(lon_max-lon_min)/2,
#                     projection='ortho',
#                     resolution = None,
#                     area_thresh=10000.,)

# %%
# basemap.shadedrelief()
# basemap.drawcoastlines(color='gray')
# basemap.drawcountries(color='gray')
# basemap.drawstates(color='gray')



# basemap.drawcoastlines()
# basemap.drawcountries()
# basemap.drawstates()
# basemap.drawmapboundary(fill_color='#46bcec')
# basemap.fillcontinents(color = 'white',lake_color='#46bcec')

# %%
# fig = plt.figure(figsize=(12, 12))

# basemap = Basemap(projection='ortho', resolution=None, lat_0=90, lon_0=180)

# # locations on map: convert lat and lon to map projection coordinates
# xlons, ylats = basemap(xlon, ylat)

# plt.plot(xlons, ylats, 'ok', markersize=1)

# # draw a circle on map on 60N  
# basemap.drawparallels([60], color='red') #, labels='test'????)
# plt.title('Study Region, 60N', fontsize=16)

# draw_map(basemap);

# how zoom to the region?

# %%
def make_the_map(XlonSet, YlatSet):
    
    fig = plt.figure(figsize=(12, 12))

    basemap = Basemap(projection='ortho', resolution=None, lat_0=90, lon_0=180)

    # locations on map: convert lat and lon to map projection coordinates
    xlons, ylats = basemap(XlonSet, YlatSet)

    plt.plot(xlons, ylats, 'ok', markersize=1)

    # draw a circle on map on 60N  
    basemap.drawparallels([60], color='red') #, labels='test'????)
    plt.title('Study Region, 60N', fontsize=16)

    draw_map(basemap);
    return 0;

# %%
# run with oython >= 3.8
# make_the_map(xlon, ylat)

# %%
# extract transect
transect = ds_3cam.loc[(ds_3cam['lon']>230.0) & (ds_3cam['lon']<231.0)]
transect.head()
# Out:
#               lat         lon     Ca_r     Cf_r     An_r    rms
# 939987  75.686747  230.000077  0.77258  1.05064  0.57193   9.08
# 939991  75.687046  230.000447  0.77258  1.05064  0.57193  12.90
# 939995  75.687344  230.000814  0.77258  1.05064  0.57193  13.97
# 939999  75.687643  230.001182  0.77258  1.05064  0.57193  15.36
# 940003  75.687941  230.001556  0.77337  1.04748  0.57430  16.01

# %%
# create a column as index and set that column as index to plot transect

# lon_subset['index'] = [i for i in range(len(lon_subset['lon']))]
transect.index = range(1,len(transect)+1)
transect.head()

# set that column as index
# lon_subset.set_index['index']
# Out:
#          lat         lon     Ca_r     Cf_r     An_r    rms
# 1  75.686747  230.000077  0.77258  1.05064  0.57193   9.08
# 2  75.687046  230.000447  0.77258  1.05064  0.57193  12.90
# 3  75.687344  230.000814  0.77258  1.05064  0.57193  13.97
# 4  75.687643  230.001182  0.77258  1.05064  0.57193  15.36
# 5  75.687941  230.001556  0.77337  1.04748  0.57430  16.01

# %%
# select a smaller subset of transect, like the first 1000 points (or 10)
transect_small = transect.iloc[0:10]
transect_small
# Out:
#           lat         lon     Ca_r     Cf_r     An_r    rms
# 1   75.686747  230.000077  0.77258  1.05064  0.57193   9.08
# 2   75.687046  230.000447  0.77258  1.05064  0.57193  12.90
# 3   75.687344  230.000814  0.77258  1.05064  0.57193  13.97
# 4   75.687643  230.001182  0.77258  1.05064  0.57193  15.36
# 5   75.687941  230.001556  0.77337  1.04748  0.57430  16.01
# 6   75.688240  230.001928  0.77337  1.04748  0.57430  13.16
# 7   75.688539  230.002300  0.77337  1.04748  0.57430  11.26
# 8   75.688706  230.000076  0.77337  1.04748  0.57430  11.31
# 9   75.688690  230.000291  0.77337  1.04748  0.57430  13.27
# 10  75.688837  230.002670  0.77337  1.04748  0.57430   7.13

# %%
xlon270 = transect_small['lon']
ylat270 = transect_small['lat']

# %%
# run with oython>=3.8
# make_the_map(xlon270, ylat270)

# %% [markdown]
# # Extract data from MISR-estimated roughness files by using MTK library. Should use python3.6 for this purpose

# %% [markdown]
# ## Plot Transect

# %%
roughness_dir = "/media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH"

# %%
# extract MISR-estimated roughness for the same latLon locations and plot them together with ATM
transect_from_misr = []
for irow in range(transect_small.shape[0]): # each row==LatLon might fall in several blocks==POB, we open each block and will average all at the end
    
    print("DF row: %s" %irow)
    lat_lon = transect_small[['lat','lon']].iloc[irow]
    print(lat_lon)
    
    path_list = mtk.latlon_to_path_list(lat_lon[0], lat_lon[1])
    print(path_list)
    
    roughness_per_pixel_list = []
    for path in path_list:
        # Q- now that we have found many paths, how figure out to select which path?
        bls = mtk.latlon_to_bls(path, 275 , lat_lon[0], lat_lon[1])
        print(bls)
        
        # use P and B to find roughness file, open it, and extract value for LS, append it to a list, and maybe finally append the list to DF as the last column
        if path < 100:
            print(path)
            path_str = str(path).zfill(3)
            print(path_str)
            
        roughness_filepattern = "roughness_toa_refl_P"+path_str+"_*"+"_B0"+str(bls[0])+".dat"
        print(roughness_filepattern)
        rough_file_fp = os.path.join(roughness_dir, roughness_filepattern)
        print(rough_file_fp)
        
        # check if file is found on machine
        roughness_file_found_list = glob.glob(os.path.join(roughness_dir, roughness_filepattern))
        print("if more than 1 file found, there is a problem with this code and it has to be reviewed")
        print(len(roughness_file_found_list))
        
        if (len(roughness_file_found_list) <= 0):
            print("roughness file not found- continue to next path")
            continue
        # open roughness file and read pixel value- chat binary format to 2D array and read pixel value
        rough_2d_arr = np.fromfile(roughness_file_found_list[0], dtype=np.double)[0:1048576].reshape((512,-1))
        print(rough_2d_arr.shape)
        
        pixel_row = bls[1]
        pixel_col = bls[2]
        roughness_value = rough_2d_arr[int(pixel_row), int(pixel_col)]
        if roughness_value > 0:
            roughness_per_pixel_list.append(roughness_value)
    
    print("----------> rough pixels...")
    print(roughness_per_pixel_list)
    mean_roughness_per_pixel = sum(roughness_per_pixel_list)/len(roughness_per_pixel_list)
    
    transect_from_misr.append(mean_roughness_per_pixel)
# Out:
# DF row: 0
# lat     75.686747
# lon    230.000077
# Name: 1, dtype: float64
# [62, 63, 64, 65, 66, 67, 68, 69, 70, 71, 72, 73, 74, 75, 76, 77, 78, 134, 135, 136, 137, 138, 139, 140, 141, 142, 143, 144, 145, 146, 147, 148, 149]
# (29, 496.734375, 36.73486328125)
# 62
# 062
# roughness_toa_refl_P062_*_B029.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P062_*_B029.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (29, 431.9951171875, 177.80923461914062)
# 63
# 063
# roughness_toa_refl_P063_*_B029.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P063_*_B029.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (29, 363.623046875, 317.1227722167969)
# 64
# 064
# roughness_toa_refl_P064_*_B029.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P064_*_B029.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (29, 291.66015625, 454.586181640625)
# 65
# 065
# roughness_toa_refl_P065_*_B029.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P065_*_B029.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (29, 216.1513671875, 590.110595703125)
# 66
# 066
# roughness_toa_refl_P066_*_B029.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P066_*_B029.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (29, 137.1455078125, 723.6079711914062)
# 67
# 067
# roughness_toa_refl_P067_*_B029.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P067_*_B029.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (29, 54.6904296875, 854.990966796875)
# 68
# 068
# roughness_toa_refl_P068_*_B029.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P068_*_B029.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (28, 480.837890625, 984.1728515625)
# 69
# 069
# roughness_toa_refl_P069_*_B028.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P069_*_B028.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (28, 391.6416015625, 1111.0677490234375)
# 70
# 070
# roughness_toa_refl_P070_*_B028.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P070_*_B028.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (28, 299.1572265625, 1235.590576171875)
# 71
# 071
# roughness_toa_refl_P071_*_B028.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P071_*_B028.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (28, 203.4423828125, 1357.657470703125)
# 72
# 072
# roughness_toa_refl_P072_*_B028.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P072_*_B028.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (28, 104.556640625, 1477.18505859375)
# 73
# 073
# roughness_toa_refl_P073_*_B028.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P073_*_B028.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (28, 2.5615234375, 1594.0911865234375)
# 74
# 074
# roughness_toa_refl_P074_*_B028.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P074_*_B028.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (27, 409.5234375, 1644.2950439453125)
# 75
# 075
# roughness_toa_refl_P075_*_B027.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P075_*_B027.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (27, 301.505859375, 1755.716552734375)
# 76
# 076
# roughness_toa_refl_P076_*_B027.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P076_*_B027.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (27, 190.5810546875, 1864.277099609375)
# 77
# 077
# roughness_toa_refl_P077_*_B027.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P077_*_B027.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (27, 76.8173828125, 1969.899658203125)
# 78
# 078
# roughness_toa_refl_P078_*_B027.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P078_*_B027.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (11, 340.58544921875, 1945.048583984375)
# roughness_toa_refl_P078_*_B011.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P078_*_B011.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (11, 229.2099609375, 1836.94384765625)
# roughness_toa_refl_P078_*_B011.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P078_*_B011.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (11, 120.73193359375, 1725.966064453125)
# roughness_toa_refl_P078_*_B011.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P078_*_B011.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (11, 15.22119140625, 1612.1937255859375)
# roughness_toa_refl_P078_*_B011.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P078_*_B011.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (10, 424.74462890625, 1495.706298828125)
# roughness_toa_refl_P078_*_B010.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P078_*_B010.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (10, 325.36669921875, 1376.5845947265625)
# roughness_toa_refl_P078_*_B010.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P078_*_B010.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (10, 229.150390625, 1254.9107666015625)
# roughness_toa_refl_P078_*_B010.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P078_*_B010.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (10, 136.15478515625, 1130.767822265625)
# roughness_toa_refl_P078_*_B010.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P078_*_B010.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (10, 46.43896484375, 1004.239501953125)
# roughness_toa_refl_P078_*_B010.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P078_*_B010.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (9, 472.05810546875, 875.410888671875)
# roughness_toa_refl_P078_*_B09.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P078_*_B09.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 0
# roughness file not found- continue to next path
# (9, 389.06689453125, 744.3676147460938)
# roughness_toa_refl_P078_*_B09.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P078_*_B09.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 0
# roughness file not found- continue to next path
# (9, 309.51611328125, 611.1962890625)
# roughness_toa_refl_P078_*_B09.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P078_*_B09.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 0
# roughness file not found- continue to next path
# (9, 233.45556640625, 475.984130859375)
# roughness_toa_refl_P078_*_B09.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P078_*_B09.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 0
# roughness file not found- continue to next path
# (9, 160.93310546875, 338.81915283203125)
# roughness_toa_refl_P078_*_B09.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P078_*_B09.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 0
# roughness file not found- continue to next path
# (9, 91.994140625, 199.79000854492188)
# roughness_toa_refl_P078_*_B09.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P078_*_B09.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 0
# roughness file not found- continue to next path
# (9, 26.68212890625, 58.98606872558594)
# roughness_toa_refl_P078_*_B09.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P078_*_B09.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 0
# roughness file not found- continue to next path
# ----------> rough pixels...
# [14.61400321274301, 19.460511616275777, 26.11034092623213, 5.636666774749756, 16.70112046740512, 19.714713658694905, 24.40374390866846, 29.687402183000234, 20.351937678825397, 14.282429646817926]
# DF row: 1
# lat     75.687046
# lon    230.000447
# Name: 2, dtype: float64
# [62, 63, 64, 65, 66, 67, 68, 69, 70, 71, 72, 73, 74, 75, 76, 77, 78, 134, 135, 136, 137, 138, 139, 140, 141, 142, 143, 144, 145, 146, 147, 148, 149]
# (29, 496.6083984375, 36.719635009765625)
# 62
# 062
# roughness_toa_refl_P062_*_B029.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P062_*_B029.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (29, 431.8701171875, 177.79074096679688)
# 63
# 063
# roughness_toa_refl_P063_*_B029.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P063_*_B029.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (29, 363.498046875, 317.10101318359375)
# 64
# 064
# roughness_toa_refl_P064_*_B029.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P064_*_B029.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (29, 291.53515625, 454.5611572265625)
# 65
# 065
# roughness_toa_refl_P065_*_B029.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P065_*_B029.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (29, 216.02734375, 590.0823364257812)
# 66
# 066
# roughness_toa_refl_P066_*_B029.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P066_*_B029.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (29, 137.0224609375, 723.5765380859375)
# 67
# 067
# roughness_toa_refl_P067_*_B029.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P067_*_B029.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (29, 54.568359375, 854.956298828125)
# 68
# 068
# roughness_toa_refl_P068_*_B029.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P068_*_B029.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (28, 480.716796875, 984.135009765625)
# 69
# 069
# roughness_toa_refl_P069_*_B028.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P069_*_B028.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (28, 391.521484375, 1111.0267333984375)
# 70
# 070
# roughness_toa_refl_P070_*_B028.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P070_*_B028.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (28, 299.0380859375, 1235.5465087890625)
# 71
# 071
# roughness_toa_refl_P071_*_B028.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P071_*_B028.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (28, 203.32421875, 1357.6102294921875)
# 72
# 072
# roughness_toa_refl_P072_*_B028.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P072_*_B028.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (28, 104.439453125, 1477.134765625)
# 73
# 073
# roughness_toa_refl_P073_*_B028.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P073_*_B028.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (28, 2.4462890625, 1594.037841796875)
# 74
# 074
# roughness_toa_refl_P074_*_B028.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P074_*_B028.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (27, 409.4091796875, 1644.2386474609375)
# 75
# 075
# roughness_toa_refl_P075_*_B027.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P075_*_B027.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (27, 301.3935546875, 1755.6572265625)
# 76
# 076
# roughness_toa_refl_P076_*_B027.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P076_*_B027.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (27, 190.4697265625, 1864.21484375)
# 77
# 077
# roughness_toa_refl_P077_*_B027.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P077_*_B027.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (27, 76.7080078125, 1969.83447265625)
# 78
# 078
# roughness_toa_refl_P078_*_B027.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P078_*_B027.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (11, 340.64208984375, 1944.9345703125)
# roughness_toa_refl_P078_*_B011.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P078_*_B011.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (11, 229.26904296875, 1836.83154296875)
# roughness_toa_refl_P078_*_B011.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P078_*_B011.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (11, 120.79443359375, 1725.85546875)
# roughness_toa_refl_P078_*_B011.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P078_*_B011.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (11, 15.28662109375, 1612.084716796875)
# roughness_toa_refl_P078_*_B011.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P078_*_B011.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (10, 424.81298828125, 1495.5989990234375)
# roughness_toa_refl_P078_*_B010.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P078_*_B010.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (10, 325.4375, 1376.479248046875)
# roughness_toa_refl_P078_*_B010.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P078_*_B010.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (10, 229.2236328125, 1254.807373046875)
# roughness_toa_refl_P078_*_B010.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P078_*_B010.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (10, 136.23095703125, 1130.666259765625)
# roughness_toa_refl_P078_*_B010.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P078_*_B010.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (10, 46.517578125, 1004.1400146484375)
# roughness_toa_refl_P078_*_B010.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P078_*_B010.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (9, 472.1396484375, 875.3134765625)
# roughness_toa_refl_P078_*_B09.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P078_*_B09.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 0
# roughness file not found- continue to next path
# (9, 389.15087890625, 744.2723999023438)
# roughness_toa_refl_P078_*_B09.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P078_*_B09.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 0
# roughness file not found- continue to next path
# (9, 309.6025390625, 611.103271484375)
# roughness_toa_refl_P078_*_B09.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P078_*_B09.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 0
# roughness file not found- continue to next path
# (9, 233.54443359375, 475.89337158203125)
# roughness_toa_refl_P078_*_B09.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P078_*_B09.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 0
# roughness file not found- continue to next path
# (9, 161.0244140625, 338.730712890625)
# roughness_toa_refl_P078_*_B09.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P078_*_B09.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 0
# roughness file not found- continue to next path
# (9, 92.08740234375, 199.7039794921875)
# roughness_toa_refl_P078_*_B09.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P078_*_B09.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 0
# roughness file not found- continue to next path
# (9, 26.77783203125, 58.90248107910156)
# roughness_toa_refl_P078_*_B09.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P078_*_B09.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 0
# roughness file not found- continue to next path
# ----------> rough pixels...
# [14.61400321274301, 19.460511616275777, 26.11034092623213, 5.636666774749756, 16.70112046740512, 19.714713658694905, 24.40374390866846, 29.687402183000234, 20.351937678825397, 14.282429646817926]
# DF row: 2
# lat     75.687344
# lon    230.000814
# Name: 3, dtype: float64
# [62, 63, 64, 65, 66, 67, 68, 69, 70, 71, 72, 73, 74, 75, 76, 77, 78, 134, 135, 136, 137, 138, 139, 140, 141, 142, 143, 144, 145, 146, 147, 148, 149]
# (29, 496.482421875, 36.70428466796875)
# 62
# 062
# roughness_toa_refl_P062_*_B029.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P062_*_B029.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (29, 431.7451171875, 177.77212524414062)
# 63
# 063
# roughness_toa_refl_P063_*_B029.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P063_*_B029.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (29, 363.373046875, 317.07916259765625)
# 64
# 064
# roughness_toa_refl_P064_*_B029.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P064_*_B029.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (29, 291.4111328125, 454.53607177734375)
# 65
# 065
# roughness_toa_refl_P065_*_B029.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P065_*_B029.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (29, 215.904296875, 590.0540771484375)
# 66
# 066
# roughness_toa_refl_P066_*_B029.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P066_*_B029.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (29, 136.8994140625, 723.5450439453125)
# 67
# 067
# roughness_toa_refl_P067_*_B029.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P067_*_B029.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (29, 54.4462890625, 854.921630859375)
# 68
# 068
# roughness_toa_refl_P068_*_B029.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P068_*_B029.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (28, 480.5966796875, 984.09716796875)
# 69
# 069
# roughness_toa_refl_P069_*_B028.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P069_*_B028.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (28, 391.40234375, 1110.9857177734375)
# 70
# 070
# roughness_toa_refl_P070_*_B028.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P070_*_B028.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (28, 298.919921875, 1235.50244140625)
# 71
# 071
# roughness_toa_refl_P071_*_B028.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P071_*_B028.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (28, 203.20703125, 1357.5631103515625)
# 72
# 072
# roughness_toa_refl_P072_*_B028.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P072_*_B028.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (28, 104.32421875, 1477.08447265625)
# 73
# 073
# roughness_toa_refl_P073_*_B028.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P073_*_B028.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (28, 2.33203125, 1593.984619140625)
# 74
# 074
# roughness_toa_refl_P074_*_B028.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P074_*_B028.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (27, 409.2958984375, 1644.182373046875)
# 75
# 075
# roughness_toa_refl_P075_*_B027.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P075_*_B027.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (27, 301.2822265625, 1755.597900390625)
# 76
# 076
# roughness_toa_refl_P076_*_B027.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P076_*_B027.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (27, 190.359375, 1864.152587890625)
# 77
# 077
# roughness_toa_refl_P077_*_B027.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P077_*_B027.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (27, 76.599609375, 1969.769287109375)
# 78
# 078
# roughness_toa_refl_P078_*_B027.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P078_*_B027.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (11, 340.6982421875, 1944.8212890625)
# roughness_toa_refl_P078_*_B011.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P078_*_B011.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (11, 229.32861328125, 1836.7198486328125)
# roughness_toa_refl_P078_*_B011.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P078_*_B011.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (11, 120.8564453125, 1725.745361328125)
# roughness_toa_refl_P078_*_B011.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P078_*_B011.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (11, 15.3515625, 1611.976318359375)
# roughness_toa_refl_P078_*_B011.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P078_*_B011.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (10, 424.880859375, 1495.4923095703125)
# roughness_toa_refl_P078_*_B010.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P078_*_B010.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (10, 325.50830078125, 1376.3743896484375)
# roughness_toa_refl_P078_*_B010.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P078_*_B010.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (10, 229.296875, 1254.704345703125)
# roughness_toa_refl_P078_*_B010.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P078_*_B010.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (10, 136.30712890625, 1130.5653076171875)
# roughness_toa_refl_P078_*_B010.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P078_*_B010.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (10, 46.59619140625, 1004.041015625)
# roughness_toa_refl_P078_*_B010.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P078_*_B010.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (9, 472.22119140625, 875.216552734375)
# roughness_toa_refl_P078_*_B09.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P078_*_B09.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 0
# roughness file not found- continue to next path
# (9, 389.234375, 744.1776123046875)
# roughness_toa_refl_P078_*_B09.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P078_*_B09.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 0
# roughness file not found- continue to next path
# (9, 309.6884765625, 611.0106811523438)
# roughness_toa_refl_P078_*_B09.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P078_*_B09.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 0
# roughness file not found- continue to next path
# (9, 233.63330078125, 475.8031005859375)
# roughness_toa_refl_P078_*_B09.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P078_*_B09.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 0
# roughness file not found- continue to next path
# (9, 161.115234375, 338.64276123046875)
# roughness_toa_refl_P078_*_B09.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P078_*_B09.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 0
# roughness file not found- continue to next path
# (9, 92.1806640625, 199.618408203125)
# roughness_toa_refl_P078_*_B09.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P078_*_B09.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 0
# roughness file not found- continue to next path
# (9, 26.873046875, 58.81932067871094)
# roughness_toa_refl_P078_*_B09.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P078_*_B09.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 0
# roughness file not found- continue to next path
# ----------> rough pixels...
# [14.61400321274301, 19.610041145014204, 17.288523407078632, 5.636666774749756, 16.70112046740512, 19.578560992956813, 22.00320156881172, 29.687402183000234, 20.351937678825397, 17.321666033421245]
# DF row: 3
# lat     75.687643
# lon    230.001182
# Name: 4, dtype: float64
# [62, 63, 64, 65, 66, 67, 68, 69, 70, 71, 72, 73, 74, 75, 76, 77, 78, 134, 135, 136, 137, 138, 139, 140, 141, 142, 143, 144, 145, 146, 147, 148, 149]
# (29, 496.3564453125, 36.688873291015625)
# 62
# 062
# roughness_toa_refl_P062_*_B029.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P062_*_B029.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (29, 431.619140625, 177.75344848632812)
# 63
# 063
# roughness_toa_refl_P063_*_B029.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P063_*_B029.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (29, 363.248046875, 317.0572204589844)
# 64
# 064
# roughness_toa_refl_P064_*_B029.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P064_*_B029.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (29, 291.287109375, 454.5108642578125)
# 65
# 065
# roughness_toa_refl_P065_*_B029.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P065_*_B029.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (29, 215.78125, 590.025634765625)
# 66
# 066
# roughness_toa_refl_P066_*_B029.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P066_*_B029.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (29, 136.77734375, 723.513427734375)
# 67
# 067
# roughness_toa_refl_P067_*_B029.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P067_*_B029.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (29, 54.32421875, 854.8868408203125)
# 68
# 068
# roughness_toa_refl_P068_*_B029.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P068_*_B029.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (28, 480.4755859375, 984.0592041015625)
# 69
# 069
# roughness_toa_refl_P069_*_B028.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P069_*_B028.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (28, 391.2822265625, 1110.944580078125)
# 70
# 070
# roughness_toa_refl_P070_*_B028.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P070_*_B028.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (28, 298.80078125, 1235.4581298828125)
# 71
# 071
# roughness_toa_refl_P071_*_B028.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P071_*_B028.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (28, 203.08984375, 1357.515625)
# 72
# 072
# roughness_toa_refl_P072_*_B028.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P072_*_B028.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (28, 104.20703125, 1477.0340576171875)
# 73
# 073
# roughness_toa_refl_P073_*_B028.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P073_*_B028.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (28, 2.216796875, 1593.93115234375)
# 74
# 074
# roughness_toa_refl_P074_*_B028.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P074_*_B028.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (27, 409.1826171875, 1644.1258544921875)
# 75
# 075
# roughness_toa_refl_P075_*_B027.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P075_*_B027.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (27, 301.169921875, 1755.5384521484375)
# 76
# 076
# roughness_toa_refl_P076_*_B027.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P076_*_B027.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (27, 190.2490234375, 1864.09033203125)
# 77
# 077
# roughness_toa_refl_P077_*_B027.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P077_*_B027.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (27, 76.490234375, 1969.7041015625)
# 78
# 078
# roughness_toa_refl_P078_*_B027.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P078_*_B027.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (11, 340.7548828125, 1944.707763671875)
# roughness_toa_refl_P078_*_B011.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P078_*_B011.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (11, 229.38818359375, 1836.607666015625)
# roughness_toa_refl_P078_*_B011.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P078_*_B011.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (11, 120.9189453125, 1725.634765625)
# roughness_toa_refl_P078_*_B011.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P078_*_B011.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (11, 15.4169921875, 1611.867431640625)
# roughness_toa_refl_P078_*_B011.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P078_*_B011.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (10, 424.94873046875, 1495.38525390625)
# roughness_toa_refl_P078_*_B010.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P078_*_B010.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (10, 325.5791015625, 1376.2691650390625)
# roughness_toa_refl_P078_*_B010.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P078_*_B010.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (10, 229.37060546875, 1254.60107421875)
# roughness_toa_refl_P078_*_B010.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P078_*_B010.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (10, 136.38330078125, 1130.4638671875)
# roughness_toa_refl_P078_*_B010.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P078_*_B010.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (10, 46.67529296875, 1003.9417724609375)
# roughness_toa_refl_P078_*_B010.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P078_*_B010.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (9, 472.30224609375, 875.119384765625)
# roughness_toa_refl_P078_*_B09.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P078_*_B09.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 0
# roughness file not found- continue to next path
# (9, 389.318359375, 744.0825805664062)
# roughness_toa_refl_P078_*_B09.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P078_*_B09.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 0
# roughness file not found- continue to next path
# (9, 309.775390625, 610.9178466796875)
# roughness_toa_refl_P078_*_B09.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P078_*_B09.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 0
# roughness file not found- continue to next path
# (9, 233.72216796875, 475.7125244140625)
# roughness_toa_refl_P078_*_B09.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P078_*_B09.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 0
# roughness file not found- continue to next path
# (9, 161.20654296875, 338.55450439453125)
# roughness_toa_refl_P078_*_B09.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P078_*_B09.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 0
# roughness file not found- continue to next path
# (9, 92.2744140625, 199.53256225585938)
# roughness_toa_refl_P078_*_B09.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P078_*_B09.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 0
# roughness file not found- continue to next path
# (9, 26.96875, 58.73591613769531)
# roughness_toa_refl_P078_*_B09.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P078_*_B09.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 0
# roughness file not found- continue to next path
# ----------> rough pixels...
# [14.61400321274301, 19.610041145014204, 17.288523407078632, 5.636666774749756, 16.70112046740512, 19.578560992956813, 22.00320156881172, 29.687402183000234, 20.351937678825397, 17.321666033421245]
# DF row: 4
# lat     75.687941
# lon    230.001556
# Name: 5, dtype: float64
# [62, 63, 64, 65, 66, 67, 68, 69, 70, 71, 72, 73, 74, 75, 76, 77, 78, 134, 135, 136, 137, 138, 139, 140, 141, 142, 143, 144, 145, 146, 147, 148, 149]
# (29, 496.2314453125, 36.674163818359375)
# 62
# 062
# roughness_toa_refl_P062_*_B029.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P062_*_B029.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (29, 431.494140625, 177.7354736328125)
# 63
# 063
# roughness_toa_refl_P063_*_B029.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P063_*_B029.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (29, 363.123046875, 317.0360107421875)
# 64
# 064
# roughness_toa_refl_P064_*_B029.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P064_*_B029.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (29, 291.1630859375, 454.48638916015625)
# 65
# 065
# roughness_toa_refl_P065_*_B029.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P065_*_B029.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (29, 215.6572265625, 589.9979248046875)
# 66
# 066
# roughness_toa_refl_P066_*_B029.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P066_*_B029.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (29, 136.654296875, 723.4824829101562)
# 67
# 067
# roughness_toa_refl_P067_*_B029.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P067_*_B029.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (29, 54.203125, 854.8526611328125)
# 68
# 068
# roughness_toa_refl_P068_*_B029.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P068_*_B029.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (28, 480.3544921875, 984.0218505859375)
# 69
# 069
# roughness_toa_refl_P069_*_B028.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P069_*_B028.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (28, 391.162109375, 1110.9041748046875)
# 70
# 070
# roughness_toa_refl_P070_*_B028.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P070_*_B028.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (28, 298.681640625, 1235.41455078125)
# 71
# 071
# roughness_toa_refl_P071_*_B028.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P071_*_B028.dat
# ...
# roughness_toa_refl_P078_*_B011.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P078_*_B011.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (11, 15.79248046875, 1611.64892578125)
# roughness_toa_refl_P078_*_B011.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P078_*_B011.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (10, 425.330078125, 1495.1766357421875)
# roughness_toa_refl_P078_*_B010.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P078_*_B010.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (10, 325.9658203125, 1376.0706787109375)
# roughness_toa_refl_P078_*_B010.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P078_*_B010.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (10, 229.76220703125, 1254.4127197265625)
# roughness_toa_refl_P078_*_B010.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P078_*_B010.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (10, 136.779296875, 1130.285888671875)
# roughness_toa_refl_P078_*_B010.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P078_*_B010.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (10, 47.076171875, 1003.7740478515625)
# roughness_toa_refl_P078_*_B010.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P078_*_B010.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (9, 472.70751953125, 874.9622802734375)
# roughness_toa_refl_P078_*_B09.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P078_*_B09.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 0
# roughness file not found- continue to next path
# (9, 389.7275390625, 743.93603515625)
# roughness_toa_refl_P078_*_B09.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P078_*_B09.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 0
# roughness file not found- continue to next path
# (9, 310.1875, 610.7820434570312)
# roughness_toa_refl_P078_*_B09.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P078_*_B09.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 0
# roughness file not found- continue to next path
# (9, 234.13818359375, 475.5875244140625)
# roughness_toa_refl_P078_*_B09.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P078_*_B09.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 0
# roughness file not found- continue to next path
# (9, 161.62548828125, 338.44036865234375)
# roughness_toa_refl_P078_*_B09.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P078_*_B09.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 0
# roughness file not found- continue to next path
# (9, 92.6962890625, 199.42935180664062)
# roughness_toa_refl_P078_*_B09.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P078_*_B09.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 0
# roughness file not found- continue to next path
# (9, 27.3935546875, 58.64369201660156)
# roughness_toa_refl_P078_*_B09.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P078_*_B09.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 0
# roughness file not found- continue to next path
# ----------> rough pixels...
# [14.45799080119039, 20.631548346549586, 17.288523407078632, 5.636666774749756, 16.37718540484569, 20.022727738825022, 22.00320156881172, 30.03357427598489, 20.385466951939804, 18.21657773842828]
# DF row: 9
# lat     75.688837
# lon    230.002670
# Name: 10, dtype: float64
# [62, 63, 64, 65, 66, 67, 68, 69, 70, 71, 72, 73, 74, 75, 76, 77, 78, 134, 135, 136, 137, 138, 139, 140, 141, 142, 143, 144, 145, 146, 147, 148, 149]
# (29, 495.8525390625, 36.628997802734375)
# 62
# 062
# roughness_toa_refl_P062_*_B029.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P062_*_B029.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (29, 431.1171875, 177.68048095703125)
# 63
# 063
# roughness_toa_refl_P063_*_B029.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P063_*_B029.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (29, 362.748046875, 316.9712219238281)
# 64
# 064
# roughness_toa_refl_P064_*_B029.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P064_*_B029.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (29, 290.7890625, 454.41192626953125)
# 65
# 065
# roughness_toa_refl_P065_*_B029.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P065_*_B029.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (29, 215.2861328125, 589.9137573242188)
# 66
# 066
# roughness_toa_refl_P066_*_B029.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P066_*_B029.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (29, 136.28515625, 723.388671875)
# 67
# 067
# roughness_toa_refl_P067_*_B029.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P067_*_B029.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (29, 53.8369140625, 854.749267578125)
# 68
# 068
# roughness_toa_refl_P068_*_B029.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P068_*_B029.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (28, 479.9912109375, 983.908935546875)
# 69
# 069
# roughness_toa_refl_P069_*_B028.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P069_*_B028.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (28, 390.8017578125, 1110.78173828125)
# 70
# 070
# roughness_toa_refl_P070_*_B028.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P070_*_B028.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (28, 298.3251953125, 1235.2828369140625)
# 71
# 071
# roughness_toa_refl_P071_*_B028.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P071_*_B028.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (28, 202.6181640625, 1357.327880859375)
# 72
# 072
# roughness_toa_refl_P072_*_B028.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P072_*_B028.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (28, 103.7412109375, 1476.833984375)
# 73
# 073
# roughness_toa_refl_P073_*_B028.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P073_*_B028.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (28, 1.755859375, 1593.7188720703125)
# 74
# 074
# roughness_toa_refl_P074_*_B028.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P074_*_B028.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (27, 408.7275390625, 1643.901611328125)
# 75
# 075
# roughness_toa_refl_P075_*_B027.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P075_*_B027.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (27, 300.720703125, 1755.30224609375)
# 76
# 076
# roughness_toa_refl_P076_*_B027.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P076_*_B027.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (27, 189.806640625, 1863.84228515625)
# 77
# 077
# roughness_toa_refl_P077_*_B027.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P077_*_B027.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (27, 76.0546875, 1969.4443359375)
# 78
# 078
# roughness_toa_refl_P078_*_B027.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P078_*_B027.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (11, 340.9794921875, 1944.25244140625)
# roughness_toa_refl_P078_*_B011.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P078_*_B011.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (11, 229.62451171875, 1836.15869140625)
# roughness_toa_refl_P078_*_B011.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P078_*_B011.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (11, 121.1669921875, 1725.1922607421875)
# roughness_toa_refl_P078_*_B011.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P078_*_B011.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (11, 15.6767578125, 1611.431640625)
# roughness_toa_refl_P078_*_B011.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P078_*_B011.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (10, 425.2197265625, 1494.9564208984375)
# roughness_toa_refl_P078_*_B010.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P078_*_B010.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (10, 325.861328125, 1375.84765625)
# roughness_toa_refl_P078_*_B010.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P078_*_B010.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (10, 229.66357421875, 1254.18701171875)
# roughness_toa_refl_P078_*_B010.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P078_*_B010.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (10, 136.68701171875, 1130.0577392578125)
# roughness_toa_refl_P078_*_B010.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P078_*_B010.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (10, 46.98974609375, 1003.5435791015625)
# roughness_toa_refl_P078_*_B010.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P078_*_B010.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 1
# (512, 2048)
# (9, 472.626953125, 874.7296142578125)
# roughness_toa_refl_P078_*_B09.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P078_*_B09.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 0
# roughness file not found- continue to next path
# (9, 389.6533203125, 743.701416015625)
# roughness_toa_refl_P078_*_B09.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P078_*_B09.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 0
# roughness file not found- continue to next path
# (9, 310.11962890625, 610.5455322265625)
# roughness_toa_refl_P078_*_B09.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P078_*_B09.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 0
# roughness file not found- continue to next path
# (9, 234.076171875, 475.3492431640625)
# roughness_toa_refl_P078_*_B09.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P078_*_B09.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 0
# roughness file not found- continue to next path
# (9, 161.56982421875, 338.2005615234375)
# roughness_toa_refl_P078_*_B09.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P078_*_B09.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 0
# roughness file not found- continue to next path
# (9, 92.64697265625, 199.18807983398438)
# roughness_toa_refl_P078_*_B09.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P078_*_B09.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 0
# roughness file not found- continue to next path
# (9, 27.3505859375, 58.40118408203125)
# roughness_toa_refl_P078_*_B09.dat
# /media/ehsan/6T_part1/2016/april_2016/14528_apr2016/project_april_2016_3cam/roughness_predicted_from_PH/roughness_toa_refl_P078_*_B09.dat
# if more than 1 file found, there is a problem with this code and it has to be reviewed
# 0
# roughness file not found- continue to next path
# ----------> rough pixels...
# [14.45799080119039, 20.631548346549586, 17.288523407078632, 5.636666774749756, 14.532645542215368, 20.022727738825022, 22.00320156881172, 30.03357427598489, 20.385466951939804, 18.21657773842828]

# %%
# plot transect
transect_small["rms"].plot(x=transect_small.index)#, y=transect_small)
plt.plot(transect_from_misr)

# %%
transect_from_misr
# Out:
# [19.09628700734127,
#  19.09628700734127,
#  18.279312346400616,
#  18.279312346400616,
#  18.428373999634005,
#  18.476530867408815,
#  18.505346300840376,
#  18.505346300840376,
#  18.505346300840376,
#  18.320892314577343]

# %% [markdown]
# ## statistics

# %%
transect_small.describe()
# Out:
#                lat          lon         Ca_r         Cf_r         An_r  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean     76.271993   230.761643     0.679431     0.883054     0.488551
# std       0.021084     0.028528     0.080355     0.069747     0.054496
# min      76.235474   230.710186     0.557620     0.784680     0.403920
# 25%      76.253777   230.737089     0.588510     0.848010     0.430960
# 50%      76.272048   230.761519     0.692000     0.859590     0.518230
# 75%      76.290219   230.786257     0.748380     0.895120     0.535220
# max      76.308333   230.813485     0.792400     1.031820     0.559930
#
#                rms
# count  1000.000000
# mean     16.004800
# std       9.021878
# min       5.240000
# 25%       9.052500
# 50%      13.000000
# 75%      20.580000
# max      63.740000

# %% [markdown]
# ## histogram

# %%
transect_small["rms"].hist(bins=20, alpha=1)
# Out:
# <AxesSubplot:>
